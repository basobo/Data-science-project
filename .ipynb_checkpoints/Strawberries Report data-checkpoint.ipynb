# %%
import pprint as pp
import sys
import os
from pymongo import MongoClient
from datetime import datetime
import ast
import pandas as pd




class Database:
    def __init__(self):
        # Read credentials from environment file.
        self.conn = MongoClient(
            host='my.ag.tools:27222',
            username='prod-r7',
            password='dfs2#sw!5wn3Tdks!',
            authSource='dbagtoolsplus'
        )



    def collection_volume_commodities(self):
        return self.conn.dbagtoolsplus.volume_commodities

# %%
    def collection_volume_commodities(self):
        return self.conn.dbagtoolsplus.volume_commodities
db = Database()
conn = db.collection_volume_commodities()

query = [
    {
        '$match': {'commodity': 'Strawberries', 'reportDate': datetime(2020, 7, 1)}
    }
]

response = list(conn.aggregate(query))
pp.pprint(response)
# Out:
# [{'_id': ObjectId('5f1663204e7a5fa1af8d54fa'),
#   'checksum_sha256': '06692bdb583c829ba6eacff88d5f41c3fefe28a8de8db36f0db231b2a42406cc',
#   'commodity': 'Strawberries',
#   'crawl_date': datetime.datetime(2020, 7, 20, 20, 38, 8, 434000),
#   'districtName': 'SANTA MARIA',
#   'impExpFlag': 'D',
#   'organic': False,
#   'originName': 'CALIFORNIA-CENTRAL',
#   'packageCntSum': 242475,
#   'packageDesc': 'FLTS 8 1-LB CNTRS W/LIDS',
#   'reportDate': datetime.datetime(2020, 7, 1, 0, 0),
#   'season': 2020,
#   'totalWeightSum': 1939800,
#   'transmode': 'Truck'},
#  {'_id': ObjectId('5f1663204e7a5fa1af8d54fb'),
#   'checksum_sha256': '05f4f8f1f729b45a45ad0655b089d30dbc81edc12fd868bba83e0fb5a5a30b5c',
#   'commodity': 'Strawberries',
#   'crawl_date': datetime.datetime(2020, 7, 20, 20, 38, 8, 437000),
#   'districtName': 'SALINAS-WATSONVILLE',
#   'impExpFlag': 'D',
#   'organic': False,
#   'originName': 'CALIFORNIA-CENTRAL',
#   'packageCntSum': 626719,
# ...

# %%
db = Database()
conn = db.collection_volume_commodities()

query = [
    {
        '$match': {
            'commodity': 'Strawberries', 
            'crawl_date': {'$gte': datetime(2020, 7, 20)}
        }
    }
]

response = list(conn.aggregate(query))
pp.pprint(response)
# Out:
# [{'_id': ObjectId('5f247f7d04c6e684f5a2072f'),
#   'checksum_sha256': 'a6e5382a79e47745382e4cb06747240a11e132e21fdd5311dbad626444dfef3a',
#   'commodity': 'Strawberries',
#   'crawl_date': datetime.datetime(2020, 7, 31, 13, 30, 53, 334000),
#   'districtName': 'SANTA MARIA',
#   'impExpFlag': 'D',
#   'organic': True,
#   'originName': 'CALIFORNIA-CENTRAL',
#   'packageCntSum': 41638,
#   'packageDesc': 'FLTS 8 1-LB CNTRS W/LIDS',
#   'reportDate': datetime.datetime(2020, 7, 30, 0, 0),
#   'season': 2020,
#   'totalWeightSum': 333104,
#   'transmode': 'Truck'},
#  {'_id': ObjectId('5f247f7d04c6e684f5a2072c'),
#   'checksum_sha256': 'e55dd9d934b931b40e3f0e816c289508423a325dff585b48643861f4a9584063',
#   'commodity': 'Strawberries',
#   'crawl_date': datetime.datetime(2020, 7, 31, 13, 30, 53, 327000),
#   'districtName': 'SANTA MARIA',
#   'impExpFlag': 'D',
#   'organic': False,
#   'originName': 'CALIFORNIA-CENTRAL',
#   'packageCntSum': 253275,
# ...

# %%
response_df=pd.DataFrame(response)

# %%
response_df.head()
# Out:
#                         _id          originName               packageDesc  \
# 0  5f247f7d04c6e684f5a2072f  CALIFORNIA-CENTRAL  FLTS 8 1-LB CNTRS W/LIDS
# 1  5f247f7d04c6e684f5a2072c  CALIFORNIA-CENTRAL  FLTS 8 1-LB CNTRS W/LIDS
# 2  5f247f7d04c6e684f5a2072e  CALIFORNIA-CENTRAL  FLTS 8 1-LB CNTRS W/LIDS
# 3  5f247f7d04c6e684f5a2072d  CALIFORNIA-CENTRAL  FLTS 8 1-LB CNTRS W/LIDS
# 4  5f232dfa04c6e608530fb086  CALIFORNIA-CENTRAL  FLTS 8 1-LB CNTRS W/LIDS
#
#    packageCntSum  totalWeightSum         districtName  season transmode  \
# 0        41638.0          333104          SANTA MARIA    2020     Truck
# 1       253275.0         2026200          SANTA MARIA    2020     Truck
# 2        90504.0          724032  SALINAS-WATSONVILLE    2020     Truck
# 3       486363.0         3890904  SALINAS-WATSONVILLE    2020     Truck
# 4        42612.0          340896          SANTA MARIA    2020     Truck
#
#   impExpFlag     commodity  organic reportDate  \
# ...

# %%
# 18 features with 1921 points 
response_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1985 entries, 0 to 1984
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   _id              1985 non-null   object
#  1   originName       1985 non-null   object
#  2   packageDesc      1844 non-null   object
#  3   packageCntSum    1844 non-null   float64
#  4   totalWeightSum   1985 non-null   int64
#  5   districtName     1985 non-null   object
#  6   season           1985 non-null   int64
#  7   transmode        1985 non-null   object
#  8   impExpFlag       1985 non-null   object
#  9   commodity        1985 non-null   object
#  10  organic          1985 non-null   bool
#  11  reportDate       1985 non-null   datetime64[ns]
#  12  checksum_sha256  1985 non-null   object
#  13  crawl_date       1985 non-null   datetime64[ns]
#  14  pdwInd           231 non-null    object
#  15  pdwDate          231 non-null    datetime64[ns]
# ...

# %%
# Fill NaN colums with average stimation
response_df.fillna(response_df.mean())
# Out:
#                            _id          originName               packageDesc  \
# 0     5f247f7d04c6e684f5a2072f  CALIFORNIA-CENTRAL  FLTS 8 1-LB CNTRS W/LIDS
# 1     5f247f7d04c6e684f5a2072c  CALIFORNIA-CENTRAL  FLTS 8 1-LB CNTRS W/LIDS
# 2     5f247f7d04c6e684f5a2072e  CALIFORNIA-CENTRAL  FLTS 8 1-LB CNTRS W/LIDS
# 3     5f247f7d04c6e684f5a2072d  CALIFORNIA-CENTRAL  FLTS 8 1-LB CNTRS W/LIDS
# 4     5f232dfa04c6e608530fb086  CALIFORNIA-CENTRAL  FLTS 8 1-LB CNTRS W/LIDS
# ...                        ...                 ...                       ...
# 1980  5f15540f8f20cd2595f6a252  CALIFORNIA-CENTRAL  FLTS 8 1-LB CNTRS W/LIDS
# 1981  5f15540f8f20cd2595f6a250  CALIFORNIA-CENTRAL  FLTS 8 1-LB CNTRS W/LIDS
# 1982  5f15540f8f20cd2595f6a251  CALIFORNIA-CENTRAL  FLTS 8 1-LB CNTRS W/LIDS
# 1983  5f15540c8f20cd2595f6a1a7             FLORIDA  FLTS 8 1-LB CNTRS W/LIDS
# 1984  5f15540c8f20cd2595f6a1a6             FLORIDA  FLTS 8 1-LB CNTRS W/LIDS
#
# ...

# %%
# Verification after filling NaN columns
# 18 features with 1921 points 
response_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1985 entries, 0 to 1984
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   _id              1985 non-null   object
#  1   originName       1985 non-null   object
#  2   packageDesc      1844 non-null   object
#  3   packageCntSum    1844 non-null   float64
#  4   totalWeightSum   1985 non-null   int64
#  5   districtName     1985 non-null   object
#  6   season           1985 non-null   int64
#  7   transmode        1985 non-null   object
#  8   impExpFlag       1985 non-null   object
#  9   commodity        1985 non-null   object
#  10  organic          1985 non-null   bool
#  11  reportDate       1985 non-null   datetime64[ns]
#  12  checksum_sha256  1985 non-null   object
#  13  crawl_date       1985 non-null   datetime64[ns]
#  14  pdwInd           231 non-null    object
#  15  pdwDate          231 non-null    datetime64[ns]
# ...

# %%
# import seaborn library 
import seaborn as sns

# %%
# How to find missing data by using heatmap method 
# packagedesc, pdwind, pdwDate, envDesk, varietyName are all object data type -STRING
sns.heatmap(response_df.isnull(), yticklabels=False, cbar=False, cmap='Blues')

# %%
# Identification of missing data
response_df.isnull().sum()
# Out:
# _id                   0
# originName            0
# packageDesc         141
# packageCntSum       141
# totalWeightSum        0
# districtName          0
# season                0
# transmode             0
# impExpFlag            0
# commodity             0
# organic               0
# reportDate            0
# checksum_sha256       0
# crawl_date            0
# pdwInd             1754
# pdwDate            1754
# envDesc            1968
# varietyName        1983
# dtype: int64

# %%
response_df.loc[(response_df['packageCntSum'].isnull() == True), 'packageCntSum'] = response_df['packageCntSum'].mean()

# %%
response_df.isnull().sum()
# Out:
# _id                   0
# originName            0
# packageDesc         141
# packageCntSum         0
# totalWeightSum        0
# districtName          0
# season                0
# transmode             0
# impExpFlag            0
# commodity             0
# organic               0
# reportDate            0
# checksum_sha256       0
# crawl_date            0
# pdwInd             1754
# pdwDate            1754
# envDesc            1968
# varietyName        1983
# dtype: int64

# %%
# response_df.loc[(response_df['pdwDate'].isnull() == True), 'pdwDate'] = response_df['pdwDate'].mean()

# %%
response_df.isnull().sum()
# Out:
# _id                   0
# originName            0
# packageDesc         141
# packageCntSum         0
# totalWeightSum        0
# districtName          0
# season                0
# transmode             0
# impExpFlag            0
# commodity             0
# organic               0
# reportDate            0
# checksum_sha256       0
# crawl_date            0
# pdwInd             1754
# pdwDate            1754
# envDesc            1968
# varietyName        1983
# dtype: int64

# %%
# Duplicate value
response_df.duplicated().sum
# Out:
# <bound method Series.sum of 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1980    False
# 1981    False
# 1982    False
# 1983    False
# 1984    False
# Length: 1985, dtype: bool>

# %%
sns.heatmap(response_df.isnull(), yticklabels=False, cbar=False, cmap='Blues')

# %%
# let drop columns that have mean
# response_df.fillna(0)
# response_df.head(2)
# response_df.drop('pdwInd', axis=1, inplace=True)

# %% [raw]
# response_df.head(2)

# %%
response_df.head(2)
# Out:
#                         _id          originName               packageDesc  \
# 0  5f247f7d04c6e684f5a2072f  CALIFORNIA-CENTRAL  FLTS 8 1-LB CNTRS W/LIDS
# 1  5f247f7d04c6e684f5a2072c  CALIFORNIA-CENTRAL  FLTS 8 1-LB CNTRS W/LIDS
#
#    packageCntSum  totalWeightSum districtName  season transmode impExpFlag  \
# 0        41638.0          333104  SANTA MARIA    2020     Truck          D
# 1       253275.0         2026200  SANTA MARIA    2020     Truck          D
#
#       commodity  organic reportDate  \
# 0  Strawberries     True 2020-07-30
# 1  Strawberries    False 2020-07-30
#
#                                      checksum_sha256              crawl_date  \
# 0  a6e5382a79e47745382e4cb06747240a11e132e21fdd53... 2020-07-31 13:30:53.334
# 1  e55dd9d934b931b40e3f0e816c289508423a325dff585b... 2020-07-31 13:30:53.327
#
#   pdwInd pdwDate envDesc varietyName
# 0    NaN     NaT     NaN         NaN
# 1    NaN     NaT     NaN         NaN

# %%
response_df.drop('envDesc', axis=1, inplace=True)

# %%
response_df.head(2)
# Out:
#                         _id          originName               packageDesc  \
# 0  5f247f7d04c6e684f5a2072f  CALIFORNIA-CENTRAL  FLTS 8 1-LB CNTRS W/LIDS
# 1  5f247f7d04c6e684f5a2072c  CALIFORNIA-CENTRAL  FLTS 8 1-LB CNTRS W/LIDS
#
#    packageCntSum  totalWeightSum districtName  season transmode impExpFlag  \
# 0        41638.0          333104  SANTA MARIA    2020     Truck          D
# 1       253275.0         2026200  SANTA MARIA    2020     Truck          D
#
#       commodity  organic reportDate  \
# 0  Strawberries     True 2020-07-30
# 1  Strawberries    False 2020-07-30
#
#                                      checksum_sha256              crawl_date  \
# 0  a6e5382a79e47745382e4cb06747240a11e132e21fdd53... 2020-07-31 13:30:53.334
# 1  e55dd9d934b931b40e3f0e816c289508423a325dff585b... 2020-07-31 13:30:53.327
#
#   pdwInd pdwDate varietyName
# 0    NaN     NaT         NaN
# 1    NaN     NaT         NaN

# %%
response_df.drop('varietyName', axis=1, inplace=True)

# %%
sns.heatmap(response_df.isnull(), yticklabels=False, cbar=False, cmap='Blues')

# %%
response_df.drop('packageDesc', axis=1, inplace=True)

# %%
sns.heatmap(response_df.isnull(), yticklabels=False, cbar=False, cmap='Blues')

# %%
sns.boxplot(response_df.packageCntSum)

# %%
response_df[response_df.packageCntSum<=200000]
# Out:
#                            _id          originName  packageCntSum  \
# 0     5f247f7d04c6e684f5a2072f  CALIFORNIA-CENTRAL        41638.0
# 2     5f247f7d04c6e684f5a2072e  CALIFORNIA-CENTRAL        90504.0
# 4     5f232dfa04c6e608530fb086  CALIFORNIA-CENTRAL        42612.0
# 6     5f232dfa04c6e608530fb087  CALIFORNIA-CENTRAL       100933.0
# 8     5f21dc4b04c6e64c614817df  CALIFORNIA-CENTRAL        63834.0
# ...                        ...                 ...            ...
# 1980  5f15540f8f20cd2595f6a252  CALIFORNIA-CENTRAL         3472.0
# 1981  5f15540f8f20cd2595f6a250  CALIFORNIA-CENTRAL        12771.0
# 1982  5f15540f8f20cd2595f6a251  CALIFORNIA-CENTRAL          800.0
# 1983  5f15540c8f20cd2595f6a1a7             FLORIDA         2752.0
# 1984  5f15540c8f20cd2595f6a1a6             FLORIDA        54638.0
#
#       totalWeightSum         districtName  season transmode impExpFlag  \
# 0             333104          SANTA MARIA    2020     Truck          D
# ...

# %%
sns.boxplot(response_df.packageCntSum)

# %%
response_df.packageCntSum.hist()

# %%
# Statistics
response_df.describe()
# Out:
#        packageCntSum  totalWeightSum       season
# count    1985.000000    1.985000e+03  1985.000000
# mean   104094.394252    7.754336e+05  2019.411587
# std    167792.311436    1.358359e+06     0.492245
# min    -15828.000000   -2.367090e+05  2019.000000
# 25%      4397.000000    2.335200e+04  2019.000000
# 50%     28140.000000    1.364640e+05  2019.000000
# 75%    104094.394252    7.442480e+05  2020.000000
# max    906038.000000    7.248304e+06  2020.000000

# %%
sns.pairplot(response_df[['packageCntSum','totalWeightSum','season']],hue='season')

# %%
sns.violinplot(x=response_df.totalWeightSum, y=response_df.season)

# %%
response_df.corr().loc['season',:].sort_values(ascending=False)
# Out:
# season            1.000000
# totalWeightSum    0.179071
# packageCntSum     0.176168
# organic          -0.060412
# Name: season, dtype: float64

# %%
response_df.groupby('season').packageCntSum.mean().reset_index()
# Out:
#    season  packageCntSum
# 0    2019   79378.345785
# 1    2020  139428.965376

# %%
correlations=response_df.corr()

# %%
import matplotlib.pyplot as plt
f,ax=plt.subplots(figsize=(20,20))
sns.heatmap(correlations, annot=True)

# %%
response_df[['reportDate', 'crawl_date', 'pdwDate']]
# Out:
#      reportDate              crawl_date pdwDate
# 0    2020-07-30 2020-07-31 13:30:53.334     NaT
# 1    2020-07-30 2020-07-31 13:30:53.327     NaT
# 2    2020-07-30 2020-07-31 13:30:53.332     NaT
# 3    2020-07-30 2020-07-31 13:30:53.330     NaT
# 4    2020-07-29 2020-07-30 13:30:50.730     NaT
# ...         ...                     ...     ...
# 1980 2020-01-02 2020-07-20 01:21:35.116     NaT
# 1981 2020-01-02 2020-07-20 01:21:35.113     NaT
# 1982 2020-01-02 2020-07-20 01:21:35.114     NaT
# 1983 2020-01-01 2020-07-20 01:21:32.241     NaT
# 1984 2020-01-01 2020-07-20 01:21:32.239     NaT
#
# [1985 rows x 3 columns]

# %%
response_df.head(1)
# Out:
#                         _id          originName  packageCntSum  \
# 0  5f247f7d04c6e684f5a2072f  CALIFORNIA-CENTRAL        41638.0
#
#    totalWeightSum districtName  season transmode impExpFlag     commodity  \
# 0          333104  SANTA MARIA    2020     Truck          D  Strawberries
#
#    organic reportDate                                    checksum_sha256  \
# 0     True 2020-07-30  a6e5382a79e47745382e4cb06747240a11e132e21fdd53...
#
#                crawl_date pdwInd pdwDate
# 0 2020-07-31 13:30:53.334    NaN     NaT

# %%
df1=response_df[['commodity','totalWeightSum','packageCntSum']]

# %%
df1.head(3)
# Out:
#       commodity  totalWeightSum  packageCntSum
# 0  Strawberries          333104        41638.0
# 1  Strawberries         2026200       253275.0
# 2  Strawberries          724032        90504.0

# %%
heatmap_data = pd.pivot_table(df1, values='totalWeightSum', 
                     index=['commodity'], 
                     columns='packageCntSum')

# %%
sns.heatmap(heatmap_data, cmap="YlGnBu")

# %%
# correlaction coefficient
response_df.corr()
# Out:
#                 packageCntSum  totalWeightSum    season   organic
# packageCntSum        1.000000        0.988177  0.176168 -0.384290
# totalWeightSum       0.988177        1.000000  0.179071 -0.345905
# season               0.176168        0.179071  1.000000 -0.060412
# organic             -0.384290       -0.345905 -0.060412  1.000000

# %%
sns.heatmap(heatmap_data, vmin=0, vmax=2)

# %%
# Let's separate the year and put it into a separate column 
response_df['Year'] = pd.DatetimeIndex(response_df['reportDate']).year

# %%
response_df.head()
# Out:
#                         _id          originName  packageCntSum  \
# 0  5f247f7d04c6e684f5a2072f  CALIFORNIA-CENTRAL        41638.0
# 1  5f247f7d04c6e684f5a2072c  CALIFORNIA-CENTRAL       253275.0
# 2  5f247f7d04c6e684f5a2072e  CALIFORNIA-CENTRAL        90504.0
# 3  5f247f7d04c6e684f5a2072d  CALIFORNIA-CENTRAL       486363.0
# 4  5f232dfa04c6e608530fb086  CALIFORNIA-CENTRAL        42612.0
#
#    totalWeightSum         districtName  season transmode impExpFlag  \
# 0          333104          SANTA MARIA    2020     Truck          D
# 1         2026200          SANTA MARIA    2020     Truck          D
# 2          724032  SALINAS-WATSONVILLE    2020     Truck          D
# 3         3890904  SALINAS-WATSONVILLE    2020     Truck          D
# 4          340896          SANTA MARIA    2020     Truck          D
#
#       commodity  organic reportDate  \
# 0  Strawberries     True 2020-07-30
# 1  Strawberries    False 2020-07-30
# 2  Strawberries     True 2020-07-30
# ...

# %%
response_df['Month'] = pd.DatetimeIndex(response_df['totalWeightSum']).month
response_df['Day'] = pd.DatetimeIndex(response_df['packageCntSum']).day

# %%
phase_1=response_df.groupby(['totalWeightSum','crawl_date']).count()

# %%
phase_1.head()
# Out:
#                                         _id  originName  packageCntSum  \
# totalWeightSum crawl_date
# -236709        2020-07-20 01:31:30.107    1           1              1
# -126624        2020-07-20 01:23:20.731    1           1              1
# -95000         2020-07-20 01:24:19.566    1           1              1
# -20128         2020-07-20 01:28:10.325    1           1              1
#  2             2020-07-20 01:23:29.561    1           1              1
#
#                                         districtName  season  transmode  \
# totalWeightSum crawl_date
# -236709        2020-07-20 01:31:30.107             1       1          1
# -126624        2020-07-20 01:23:20.731             1       1          1
# -95000         2020-07-20 01:24:19.566             1       1          1
# -20128         2020-07-20 01:28:10.325             1       1          1
#  2             2020-07-20 01:23:29.561             1       1          1
#
# ...

# %%
fig, ax = plt.subplots(figsize=(20,10))
response_df.groupby(['packageCntSum','totalWeightSum']).mean()['season'].unstack().plot(ax=ax)

# %%
plt.figure(figsize=[15,10])

plt.subplot(211)
sns.barplot(x = 'packageCntSum', y = 'totalWeightSum', data = response_df)

plt.subplot(212)
sns.barplot(x = 'packageCntSum', y = 'totalWeightSum', data = response_df)

# %%
response_df['commodity'] = response_df['crawl_date'].map(lambda x: 1)

# %%
response_df.head(50)
# Out:
#                         _id          originName  packageCntSum  \
# 0  5f247f7d04c6e684f5a2072f  CALIFORNIA-CENTRAL        41638.0
# 1  5f247f7d04c6e684f5a2072c  CALIFORNIA-CENTRAL       253275.0
# 2  5f247f7d04c6e684f5a2072e  CALIFORNIA-CENTRAL        90504.0
# 3  5f247f7d04c6e684f5a2072d  CALIFORNIA-CENTRAL       486363.0
#
#    totalWeightSum         districtName  season transmode impExpFlag  \
# 0          333104          SANTA MARIA    2020     Truck          D
# 1         2026200          SANTA MARIA    2020     Truck          D
# 2          724032  SALINAS-WATSONVILLE    2020     Truck          D
# 3         3890904  SALINAS-WATSONVILLE    2020     Truck          D
#
#    commodity  organic reportDate  \
# 0          1     True 2020-07-30
# 1          1    False 2020-07-30
# 2          1     True 2020-07-30
# 3          1    False 2020-07-30
#
#                                      checksum_sha256              crawl_date  \
# ...

# %%
plt.figure(figsize=(10,10))
sns.countplot(response_df['commodity'])
plt.ylabel('Number of record')
plt.xlabel('commodity')
plt.title('Number of counts ')
# Out:
# Text(0.5, 1.0, 'Number of counts ')

# %%
df_type = response_df.groupby(['_id'])['commodity'].sum()

# %%
response_df.to_csv('C:/Users/bruno/Desktop/Data science for Business/production_straw.csv')

# %%
response_df.originName
# Out:
# 0       CALIFORNIA-CENTRAL
# 1       CALIFORNIA-CENTRAL
# 2       CALIFORNIA-CENTRAL
# 3       CALIFORNIA-CENTRAL
# 4       CALIFORNIA-CENTRAL
#                ...
# 1980    CALIFORNIA-CENTRAL
# 1981    CALIFORNIA-CENTRAL
# 1982    CALIFORNIA-CENTRAL
# 1983               FLORIDA
# 1984               FLORIDA
# Name: originName, Length: 1985, dtype: object
